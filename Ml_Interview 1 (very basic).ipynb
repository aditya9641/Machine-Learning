# %%
import numpy as np
import pandas as pd
import sklearn

print("Setup successful 🚀")
# Out:
# Setup successful 🚀

# %%
# What is Machine Learning?

# Machine Learning is a method where computers learn patterns from data
# and make predictions without being explicitly programmed.

# %%
# Supervised Learning: Data with labels
# Unsupervised Learning: Data without labels

# Regression: Predict numbers
# Classification: Predict categories

# Feature: Input variable
# Target: Output variable

# %%
# Overfitting: good on training, bad on new data
# Underfitting: poor performance overall

# Train data: used to train model
# Test data: used to evaluate model

# Accuracy: correct / total (20/100)
# Precision: correct positives / predicted positives (10/15)
# Recall: correct positives / actual positives (catched) (10/20)

# %%
# Linear Regression: predicts continuous values using best-fit line

# Logistic Regression: predicts probability for classification (0 or 1)

# %%
# Decision Tree: model that splits data using conditions (like if-else)

# Random Forest: collection of multiple decision trees to improve accuracy

# %%
# KNN: classifies based on nearest neighbors

# K-Means: groups data into clusters based on similarity

# %%
# SVM: finds best boundary to separate classes

# Naive Bayes: uses probability to classify data

# %%
# 1 ml project

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error
from sklearn.datasets import fetch_california_housing

# Load dataset
data = fetch_california_housing()

X = pd.DataFrame(data.data, columns=data.feature_names)
y = data.target

# Split data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Train model
model = LinearRegression()
model.fit(X_train, y_train)

# Predict
predictions = model.predict(X_test)

# Evaluate
error = mean_absolute_error(y_test, predictions)

print("Mean Absolute Error:", error)
# Out:
# Mean Absolute Error: 0.5232441909963026
